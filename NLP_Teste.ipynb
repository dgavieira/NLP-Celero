# %% [markdown]
# <a href="https://colab.research.google.com/github/dgavieira/NLP-Celero/blob/exploratory-analysis/NLP_Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Upload do Dataset

# %%
import pandas as pd

# %% [markdown]
# ## Upload de dados de teste

# %% [markdown]
# ### Teste - Sentimento NEGATIVO

# %%
df_test_neg = pd.read_csv('https://drive.google.com/uc?id=1tUxBvBO_6wOEGe3fgxmU2wCDuUnqNeot', encoding='utf8', header=None)
df_test_neg = df_test_neg.T # transpondo o dataframe para ficar no formato usual
df_test_neg
# Out:
#                                                     0
# 0   Once again Mr. Costner has dragged out a movie...
# 1   Years ago, when DARLING LILI played on TV, it ...
# 2   Julie Andrews satirically prods her own goody-...
# 3   Blake Edwards tried very hard to change Julie ...
# 4   An obvious vanity press for Julie in her first...
# 5   Some may go for a film like this but I most as...
# 6   Few movies have dashed expectations and upset ...
# 7   For years, I've been a big fan of Park's work ...
# 8   Might end up being the biggest disappointment ...
# 9   Bloody Birthday opens to a shot of Meadowvale ...
# 10  This movie cannot be serious because it has a ...
# 11  This is a pale imitation of 'Officer and a Gen...
# 12  A mean spirited, repulsive horror film about 3...
# 13  Bloody Birthday is a totally rubbish slasher m...
# 14  When you make a film with a killer-kids premis...
# 15  When people say children are annoying u think ...
# ...

# %% [markdown]
# > Marcando a coluna de reviews negativos

# %%
df_test_neg.columns = ['reviews']
df_test_neg
# Out:
#                                               reviews
# 0   Once again Mr. Costner has dragged out a movie...
# 1   Years ago, when DARLING LILI played on TV, it ...
# 2   Julie Andrews satirically prods her own goody-...
# 3   Blake Edwards tried very hard to change Julie ...
# 4   An obvious vanity press for Julie in her first...
# 5   Some may go for a film like this but I most as...
# 6   Few movies have dashed expectations and upset ...
# 7   For years, I've been a big fan of Park's work ...
# 8   Might end up being the biggest disappointment ...
# 9   Bloody Birthday opens to a shot of Meadowvale ...
# 10  This movie cannot be serious because it has a ...
# 11  This is a pale imitation of 'Officer and a Gen...
# 12  A mean spirited, repulsive horror film about 3...
# 13  Bloody Birthday is a totally rubbish slasher m...
# 14  When you make a film with a killer-kids premis...
# 15  When people say children are annoying u think ...
# ...

# %% [markdown]
# > marcando os dados de teste com o sentimento negativo

# %%
df_test_neg.loc[:,'sentiment'] = 'neg'
df_test_neg
# Out:
#                                               reviews sentiment
# 0   Once again Mr. Costner has dragged out a movie...       neg
# 1   Years ago, when DARLING LILI played on TV, it ...       neg
# 2   Julie Andrews satirically prods her own goody-...       neg
# 3   Blake Edwards tried very hard to change Julie ...       neg
# 4   An obvious vanity press for Julie in her first...       neg
# 5   Some may go for a film like this but I most as...       neg
# 6   Few movies have dashed expectations and upset ...       neg
# 7   For years, I've been a big fan of Park's work ...       neg
# 8   Might end up being the biggest disappointment ...       neg
# 9   Bloody Birthday opens to a shot of Meadowvale ...       neg
# 10  This movie cannot be serious because it has a ...       neg
# 11  This is a pale imitation of 'Officer and a Gen...       neg
# 12  A mean spirited, repulsive horror film about 3...       neg
# 13  Bloody Birthday is a totally rubbish slasher m...       neg
# ...

# %% [markdown]
# ### Teste - Sentimento POSITIVO

# %%
df_test_pos = pd.read_csv('https://drive.google.com/uc?id=1sk4SKAds3zUybi1J-TkVgiRf_NMZxmpF', encoding='utf8', header=None)
df_test_pos = df_test_pos.T # transpondo o dataframe para ficar no formato usual
df_test_pos
# Out:
#                                                     0
# 0   I went and saw this movie last night after bei...
# 1   If you had asked me how the movie was througho...
# 2   I was looking forward to The Guardian, but whe...
# 3   I was pleasantly surprised to find this movie ...
# 4   I work at a movie theater and every Thursday n...
# 5   I attended an advance screening of this film n...
# 6   As others that have commented around the web.....
# 7   I went to an advance screening of this movie t...
# 8   Brilliant and moving performances by Tom Court...
# 9   The Dresser is perhaps the most refined of bac...
# 10  This is one of my three all-time favorite movi...
# 11  My boyfriend and I went to watch The Guardian....
# 12  The many other comments about the film say it ...
# 13  The Dresser is a small but absolutely wonderfu...
# 14  What is worth mentioning that is omitted in th...
# 15  Anyone who appreciates fine acting and ringing...
# ...

# %% [markdown]
# > Marcando os dados da coluna de reviews

# %%
df_test_pos.columns = ['reviews']
df_test_pos
# Out:
#                                               reviews
# 0   I went and saw this movie last night after bei...
# 1   If you had asked me how the movie was througho...
# 2   I was looking forward to The Guardian, but whe...
# 3   I was pleasantly surprised to find this movie ...
# 4   I work at a movie theater and every Thursday n...
# 5   I attended an advance screening of this film n...
# 6   As others that have commented around the web.....
# 7   I went to an advance screening of this movie t...
# 8   Brilliant and moving performances by Tom Court...
# 9   The Dresser is perhaps the most refined of bac...
# 10  This is one of my three all-time favorite movi...
# 11  My boyfriend and I went to watch The Guardian....
# 12  The many other comments about the film say it ...
# 13  The Dresser is a small but absolutely wonderfu...
# 14  What is worth mentioning that is omitted in th...
# 15  Anyone who appreciates fine acting and ringing...
# ...

# %% [markdown]
# > Marcando os reviews a seguir com o sentimento positivo.

# %%
df_test_pos.loc[:,'sentiment'] = 'pos'
df_test_pos
# Out:
#                                               reviews sentiment
# 0   I went and saw this movie last night after bei...       pos
# 1   If you had asked me how the movie was througho...       pos
# 2   I was looking forward to The Guardian, but whe...       pos
# 3   I was pleasantly surprised to find this movie ...       pos
# 4   I work at a movie theater and every Thursday n...       pos
# 5   I attended an advance screening of this film n...       pos
# 6   As others that have commented around the web.....       pos
# 7   I went to an advance screening of this movie t...       pos
# 8   Brilliant and moving performances by Tom Court...       pos
# 9   The Dresser is perhaps the most refined of bac...       pos
# 10  This is one of my three all-time favorite movi...       pos
# 11  My boyfriend and I went to watch The Guardian....       pos
# 12  The many other comments about the film say it ...       pos
# 13  The Dresser is a small but absolutely wonderfu...       pos
# ...

# %% [markdown]
# ## Concatenando datasets de teste

# %%
df_test = pd.concat([df_test_neg, df_test_pos], axis=0, ignore_index=True)
df_test
# Out:
#                                                reviews sentiment
# 0    Once again Mr. Costner has dragged out a movie...       neg
# 1    Years ago, when DARLING LILI played on TV, it ...       neg
# 2    Julie Andrews satirically prods her own goody-...       neg
# 3    Blake Edwards tried very hard to change Julie ...       neg
# 4    An obvious vanity press for Julie in her first...       neg
# ..                                                 ...       ...
# 97   I only went to see this movie because I have a...       pos
# 98   I was fortunate enough to see this movie on pr...       pos
# 99   Our family (and the entire sold out sneak prev...       pos
# 100  I'm a Petty Officer 1st Class (E-6) and have b...       pos
# 101  I've seen this story before but my kids haven'...       pos
#
# [102 rows x 2 columns]

# %% [markdown]
# ## Upload - Datasets de Treinamento

# %% [markdown]
# ### Treinamento - Sentimento NEGATIVO

# %%
df_train_neg = pd.read_csv('https://drive.google.com/uc?id=1_y0TFz5lRyTWRPOdukm8jL4gmNBKtf6q', encoding='utf8', header=None)
df_train_neg = df_train_neg.T # transpondo o dataframe para ficar no formato usual
df_train_neg
# Out:
#                                                     0
# 0   Story of a man who has unnatural feelings for ...
# 1   This film had a lot of promise, and the plot w...
# 2   If you look at Corey Large's information here ...
# 3   All I could think of while watching this movie...
# 4   Weak plot, predictable violence, only semi int...
# 5   There are times when finishing a film one wish...
# 6   This is it. This is the one. This is the worst...
# 7   There are lots of extremely good-looking peopl...
# 8   Nine minutes of psychedelic, pulsating, often ...
# 9   This is an art film that was either made in 19...
# 10  I am a big fan of Arnold Vosloo. Finally seein...
# 11  Robert DeNiro plays the most unbelievably inte...
# 12  This movie was terrible. at first i just read ...
# 13  What was with all the Turkish actors? No offen...
# 14  I saw this DVD in my friends house and thought...
# 15  I rented this one on DVD without any prior kno...
# ...

# %%
df_train_neg.columns = ['reviews']
df_train_neg
# Out:
#                                               reviews
# 0   Story of a man who has unnatural feelings for ...
# 1   This film had a lot of promise, and the plot w...
# 2   If you look at Corey Large's information here ...
# 3   All I could think of while watching this movie...
# 4   Weak plot, predictable violence, only semi int...
# 5   There are times when finishing a film one wish...
# 6   This is it. This is the one. This is the worst...
# 7   There are lots of extremely good-looking peopl...
# 8   Nine minutes of psychedelic, pulsating, often ...
# 9   This is an art film that was either made in 19...
# 10  I am a big fan of Arnold Vosloo. Finally seein...
# 11  Robert DeNiro plays the most unbelievably inte...
# 12  This movie was terrible. at first i just read ...
# 13  What was with all the Turkish actors? No offen...
# 14  I saw this DVD in my friends house and thought...
# 15  I rented this one on DVD without any prior kno...
# ...

# %%
df_train_neg.loc[:,'sentiment'] = 'neg'
df_train_neg
# Out:
#                                               reviews sentiment
# 0   Story of a man who has unnatural feelings for ...       neg
# 1   This film had a lot of promise, and the plot w...       neg
# 2   If you look at Corey Large's information here ...       neg
# 3   All I could think of while watching this movie...       neg
# 4   Weak plot, predictable violence, only semi int...       neg
# 5   There are times when finishing a film one wish...       neg
# 6   This is it. This is the one. This is the worst...       neg
# 7   There are lots of extremely good-looking peopl...       neg
# 8   Nine minutes of psychedelic, pulsating, often ...       neg
# 9   This is an art film that was either made in 19...       neg
# 10  I am a big fan of Arnold Vosloo. Finally seein...       neg
# 11  Robert DeNiro plays the most unbelievably inte...       neg
# 12  This movie was terrible. at first i just read ...       neg
# 13  What was with all the Turkish actors? No offen...       neg
# ...

# %% [markdown]
# ### Treinamento - Sentimento POSITIVO

# %%
df_train_pos = pd.read_csv('https://drive.google.com/uc?id=1HCybdmPv4gOAI2kQCb5lz8aTMDTNVrr0', encoding='utf8', header=None)
df_train_pos = df_train_pos.T # transpondo o dataframe para ficar no formato usual
df_train_pos
# Out:
#                                                     0
# 0   Bromwell High is a cartoon comedy. It ran at t...
# 1   I'm a male, not given to women's movies, but t...
# 2   Liked Stanley & Iris very much. Acting was ver...
# 3   Liked Stanley & Iris very much. Acting was ver...
# 4   The production quality, cast, premise, authent...
# 5   This film has a special place in my heart, as ...
# 6   I guess if a film has magic, I don't need it t...
# 7   I found this to be a so-so romance/drama that ...
# 8   This is a complex film that explores the effec...
# 9   `Stanley and Iris' is a heart warming film abo...
# 10  I just read the comments of TomReynolds2004 an...
# 11  If you like adult comedy cartoons, like South ...
# 12  'Stanley and Iris' show the triumph of the hum...
# 13  This may not be a memorable classic, but it is...
# 14  If you fast forward through the horrible singi...
# 15  OK, so the musical pieces were poorly written ...
# ...

# %%
df_train_pos.columns = ['reviews']
df_train_pos
# Out:
#                                               reviews
# 0   Bromwell High is a cartoon comedy. It ran at t...
# 1   I'm a male, not given to women's movies, but t...
# 2   Liked Stanley & Iris very much. Acting was ver...
# 3   Liked Stanley & Iris very much. Acting was ver...
# 4   The production quality, cast, premise, authent...
# 5   This film has a special place in my heart, as ...
# 6   I guess if a film has magic, I don't need it t...
# 7   I found this to be a so-so romance/drama that ...
# 8   This is a complex film that explores the effec...
# 9   `Stanley and Iris' is a heart warming film abo...
# 10  I just read the comments of TomReynolds2004 an...
# 11  If you like adult comedy cartoons, like South ...
# 12  'Stanley and Iris' show the triumph of the hum...
# 13  This may not be a memorable classic, but it is...
# 14  If you fast forward through the horrible singi...
# 15  OK, so the musical pieces were poorly written ...
# ...

# %%
df_train_pos.loc[:,'sentiment'] = 'pos'
df_train_pos
# Out:
#                                               reviews sentiment
# 0   Bromwell High is a cartoon comedy. It ran at t...       pos
# 1   I'm a male, not given to women's movies, but t...       pos
# 2   Liked Stanley & Iris very much. Acting was ver...       pos
# 3   Liked Stanley & Iris very much. Acting was ver...       pos
# 4   The production quality, cast, premise, authent...       pos
# 5   This film has a special place in my heart, as ...       pos
# 6   I guess if a film has magic, I don't need it t...       pos
# 7   I found this to be a so-so romance/drama that ...       pos
# 8   This is a complex film that explores the effec...       pos
# 9   `Stanley and Iris' is a heart warming film abo...       pos
# 10  I just read the comments of TomReynolds2004 an...       pos
# 11  If you like adult comedy cartoons, like South ...       pos
# 12  'Stanley and Iris' show the triumph of the hum...       pos
# 13  This may not be a memorable classic, but it is...       pos
# ...

# %% [markdown]
# ### Treinamento - UNSUPOSED

# %%
df_train_unsup = pd.read_csv('https://drive.google.com/uc?id=1KDFnhw4Syj9I9PFfcNSQTZWu8Ohi907C', encoding='utf8', header=None)
df_train_unsup = df_train_unsup.T # transpondo o dataframe para ficar no formato usual
df_train_unsup
# Out:
#                                                     0
# 0   I admit, the great majority of films released ...
# 1   Finally, I got to see this legendary masterpie...
# 2   Watching this film was like reliving the jobs ...
# 3   Evocative, funny look at four women stuck in t...
# 4   I thought I'd do a quick review. Actually I di...
# 5   Clockwatchers surprised me in many ways. At fi...
# 6   Transcendently beautiful in moments outside th...
# 7   I have been an office temp, and this portrays ...
# 8   I've been reading the comments and I'm not sur...
# 9   Clockwatchers is a very funny little film that...
# 10  This was clearly written by someone who has go...
# 11  This is a very strange film that was long thou...
# 12  For some reason I'd been resisting seeing this...
# 13  Funny women Posey and Kudrow star in this popu...
# 14  I have never worked as an office temp before, ...
# 15  The four leads are very effective as the disaf...
# ...

# %%
df_train_unsup.columns = ['reviews']
df_train_unsup
# Out:
#                                               reviews
# 0   I admit, the great majority of films released ...
# 1   Finally, I got to see this legendary masterpie...
# 2   Watching this film was like reliving the jobs ...
# 3   Evocative, funny look at four women stuck in t...
# 4   I thought I'd do a quick review. Actually I di...
# 5   Clockwatchers surprised me in many ways. At fi...
# 6   Transcendently beautiful in moments outside th...
# 7   I have been an office temp, and this portrays ...
# 8   I've been reading the comments and I'm not sur...
# 9   Clockwatchers is a very funny little film that...
# 10  This was clearly written by someone who has go...
# 11  This is a very strange film that was long thou...
# 12  For some reason I'd been resisting seeing this...
# 13  Funny women Posey and Kudrow star in this popu...
# 14  I have never worked as an office temp before, ...
# 15  The four leads are very effective as the disaf...
# ...

# %%
df_train_unsup.loc[:,'sentiment'] = 'unsup'
df_train_unsup
# Out:
#                                               reviews sentiment
# 0   I admit, the great majority of films released ...     unsup
# 1   Finally, I got to see this legendary masterpie...     unsup
# 2   Watching this film was like reliving the jobs ...     unsup
# 3   Evocative, funny look at four women stuck in t...     unsup
# 4   I thought I'd do a quick review. Actually I di...     unsup
# 5   Clockwatchers surprised me in many ways. At fi...     unsup
# 6   Transcendently beautiful in moments outside th...     unsup
# 7   I have been an office temp, and this portrays ...     unsup
# 8   I've been reading the comments and I'm not sur...     unsup
# 9   Clockwatchers is a very funny little film that...     unsup
# 10  This was clearly written by someone who has go...     unsup
# 11  This is a very strange film that was long thou...     unsup
# 12  For some reason I'd been resisting seeing this...     unsup
# 13  Funny women Posey and Kudrow star in this popu...     unsup
# ...

# %% [markdown]
# ## Concatenando datasets de treino

# %%
df_train = pd.concat([df_train_neg, df_train_pos, df_train_unsup], axis=0, ignore_index=True)
df_train
# Out:
#                                                reviews sentiment
# 0    Story of a man who has unnatural feelings for ...       neg
# 1    This film had a lot of promise, and the plot w...       neg
# 2    If you look at Corey Large's information here ...       neg
# 3    All I could think of while watching this movie...       neg
# 4    Weak plot, predictable violence, only semi int...       neg
# ..                                                 ...       ...
# 148  Turner Classic Movies showed this silent, B&W ...     unsup
# 149  Enjoyed viewing this 1927 Silent Film from the...     unsup
# 150  Like TWO ARABIAN KNIGHTS, a couple of American...     unsup
# 151  TWO ARABIAN KNIGHTS has been restored by Flick...     unsup
# 152  TCM came through by acquiring this wonderful, ...     unsup
#
# [153 rows x 2 columns]

# %% [markdown]
# ## Concatenando datasets totais

# %% [markdown]
# > O dataset abaixo tem o formato semelhante ao dataset do IMDB no link:
# [IMDB reviews dataset](https://www.kaggle.com/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews).
#
# > Para que a extração demorasse menos tempo, optou-se por fazer um exemplo menor com as 50 entradas de cada pasta, conforme o branch [Data-Extraction](https://github.com/dgavieira/NLP-Celero/tree/data-extraction) no repositório.

# %%
df_total = pd.concat([df_train, df_test], axis=0, ignore_index=True)
df_total
# Out:
#                                                reviews sentiment
# 0    Story of a man who has unnatural feelings for ...       neg
# 1    This film had a lot of promise, and the plot w...       neg
# 2    If you look at Corey Large's information here ...       neg
# 3    All I could think of while watching this movie...       neg
# 4    Weak plot, predictable violence, only semi int...       neg
# ..                                                 ...       ...
# 250  I only went to see this movie because I have a...       pos
# 251  I was fortunate enough to see this movie on pr...       pos
# 252  Our family (and the entire sold out sneak prev...       pos
# 253  I'm a Petty Officer 1st Class (E-6) and have b...       pos
# 254  I've seen this story before but my kids haven'...       pos
#
# [255 rows x 2 columns]

# %% [markdown]
# # Verificando IMDB Dataset of 50k Movie Reviews

# %%
df_imdb = pd.read_csv('https://drive.google.com/uc?id=1dYzliUyfAU3jepZpUeBJE16elVxOYZHl', encoding='utf8')
df_imdb
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# > Observa-se que os datasets são semelhantes, portanto, para fins de análise exploratória, posso utilizar a variável df_imdb para os itens a seguir.

# %% [markdown]
# # Análise Exploratória

# %%
from sklearn import linear_model
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Mudando classificação de [negative, positive] para [0,1]

# %%
classificacao = df_imdb["sentiment"].replace(["negative", "positive"],[0,1])
df_imdb["classificacao"] = classificacao
df_imdb.head()
# Out:
#                                               review sentiment  classificacao
# 0  One of the other reviewers has mentioned that ...  positive              1
# 1  A wonderful little production. <br /><br />The...  positive              1
# 2  I thought this was a wonderful way to spend ti...  positive              1
# 3  Basically there's a family where a little boy ...  negative              0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive              1

# %%
df_imdb.tail()
# Out:
#                                                   review  ... classificacao
# 49995  I thought this movie did a down right good job...  ...             1
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  ...             0
# 49997  I am a Catholic taught in parochial elementary...  ...             0
# 49998  I'm going to have to disagree with the previou...  ...             0
# 49999  No one expects the Star Trek movies to be high...  ...             0
#
# [5 rows x 3 columns]

# %%
print(df_imdb['classificacao'].value_counts())
# Out:
# 1    25000
# 0    25000
# Name: classificacao, dtype: int64

# %% [markdown]
# > observo que os dados são perfeitamente equilibrados.
#
# * 25000 dados marcados como negativos.
# * 25000 dados marcados como positivos.

# %% [markdown]
# ## Vetorizando palavras em um bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vetorizar = CountVectorizer(lowercase=False, max_features=50)
bag_of_words = vetorizar.fit_transform(df_imdb['review'])

# %%
print(bag_of_words.shape)
# Out:
# (50000, 50)

# %%
vetorizar.get_feature_names()
# Out:
# ['It',
#  'The',
#  'This',
#  'about',
#  'all',
#  'an',
#  'and',
#  'are',
#  'as',
#  'at',
#  'be',
#  'br',
#  'but',
#  'by',
#  'can',
#  'film',
#  'for',
#  'from',
#  'good',
#  'has',
#  'have',
#  'he',
#  'her',
#  'his',
#  'in',
#  'is',
#  'it',
#  'just',
#  'like',
#  'more',
#  'movie',
#  'not',
#  'of',
#  'on',
#  'one',
#  'or',
#  'out',
#  'so',
#  'some',
#  'that',
#  'the',
#  'they',
#  'this',
#  'to',
#  'up',
#  'very',
#  'was',
#  'who',
#  'with',
#  'you']

# %%
vetorizado = pd.DataFrame.sparse.from_spmatrix(bag_of_words, columns = vetorizar.get_feature_names())
vetorizado
# Out:
#        It  The  This  about  all  an  and  ...  to  up  very  was  who  with  you
# 0       2    2     1      1    1   1    6  ...   6   0     0    3    2     5    3
# 1       1    3     0      1    2   0    7  ...   2   0     2    0    0     3    0
# 2       0    1     2      0    0   0    4  ...   4   0     0    4    0     2    0
# 3       0    0     1      0    3   0    3  ...   3   0     0    0    0     3    2
# 4       0    2     2      2    2   0    5  ...   7   0     0    0    0     1    0
# ...    ..  ...   ...    ...  ...  ..  ...  ...  ..  ..   ...  ...  ...   ...  ...
# 49995   2    0     0      1    1   0    7  ...   5   0     1    2    2     0    2
# 49996   1    3     0      0    1   0    2  ...   3   0     0    4    1     0    1
# 49997   0    0     1      0    1   1    6  ...   4   0     1    1    1     1    0
# 49998   1    0     1      2    1   0    8  ...   6   0     0    2    0     3    1
# ...

# %% [markdown]
# ## Classificando sentimentos com Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
treino, teste, classe_treino, classe_teste = train_test_split(bag_of_words,
                                                              df_imdb['classificacao'],
                                                              random_state=42)

# %%
print(treino.shape)
print(teste.shape)
# Out:
# (37500, 50)
# (12500, 50)

# %% [markdown]
# ### Mostrando os resultados em termos de probabilidade

# %%
regressao_logistica = LogisticRegression(solver='lbfgs')
regressao_logistica.fit(treino, classe_treino)
previsao_teste = regressao_logistica.predict_proba(teste)
print(previsao_teste)
# Out:
# [[0.59665069 0.40334931]
#  [0.45141023 0.54858977]
#  [0.68065739 0.31934261]
#  ...
#  [0.54112719 0.45887281]
#  [0.24831594 0.75168406]
#  [0.5179249  0.4820751 ]]

# %% [markdown]
# ### Mostrando os resultados em termos booleanos

# %%
previsao_test_bol = previsao_teste[:,1] >= 0.5
print(previsao_test_bol)
# Out:
# [False  True False ... False  True False]

# %% [markdown]
# ### Mostrando os resultados em termos binários

# %%
import numpy as np

# %%
previsao_teste_int = previsao_test_bol.astype(np.int)
print(previsao_teste_int)
# Out:
# [0 1 0 ... 0 1 0]

# %% [markdown]
# ### Mostrando os resultados em termos de porcentagem

# %%
from sklearn.metrics import accuracy_score
acuracia_teste = accuracy_score(classe_teste, previsao_teste_int)
print("Precisão do Modelo: {:.2f}%".format(acuracia_teste*100))
# Out:
# Precisão do Modelo: 65.20%

# %% [markdown]
# > Observo que o modelo treinado por Regressão Logística sem nenhum tratamento de NLP atinge 65.20% de acurácia. É possível melhorar a performance utilizando técnicas de processamento de linguagem natural - o recomendável - ou mudando o modelo. Para fazer o teste, irei verificar utilizando uma SVM Linear.

# %% [markdown]
# ## Classificando com SVM

# %%
svm_linearSVC = svm.LinearSVC()
svm_linearSVC.fit(treino, classe_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
svm_linearSVC.predict(teste)
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
score_svm = svm_linearSVC.score(teste, classe_teste)
print("Precisão do Modelo: {:.2f}%".format(score_svm*100))
# Out:
# Precisão do Modelo: 65.16%

# %% [markdown]
# ## Comparando modelos de Regressão Logística e LinearSVC

# %%
print("Precisão do Modelo Linear Regression: {:.2f}%".format(acuracia_teste*100))
print("Precisão do Modelo LinearSVC: {:.2f}%".format(score_svm*100))
# Out:
# Precisão do Modelo Linear Regression: 65.20%
# Precisão do Modelo LinearSVC: 65.16%

# %% [markdown]
# # Executando técnicas de Natural Language Processing
